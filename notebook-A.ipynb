# %%
# %run "/Workspace/Users/sailakshmi21.k@gmail.com/notebook-B"

# %%
print("person name is",person_name)
print("person location is",person_loc)

# %%
lst = [11,12,13,14]
res = getlstsum(lst)
print(res)
